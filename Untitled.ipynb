# %%
import dadrah.analysis.root_plotting_util as ru
# Out:
# Welcome to JupyROOT 6.18/04

# %%
import numpy as np

# %%
a = np.random.normal(size=5000)
b = np.random.normal(size=7000)

# %%
from importlib import reload
reload(ru)
ru.make_root_plot(a,b)
# Out:
# min -3.5790474877583147, max 4.1727938100856665
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created

# %%
ru.make_root_plot(a,b)
